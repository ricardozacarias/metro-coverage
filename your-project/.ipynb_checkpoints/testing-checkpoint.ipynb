# %% [markdown]
# # TESTING SCRIPT

# %%
import geopandas
import geoplot
import numpy as np
import pandas as pd
import random
import geojson
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import plotly.express as px
import tqdm
import seaborn as sns
import matplotlib as mpl

# %%
# open datasets
london = geopandas.read_file('C:/Users/Zaca/Documents/Datasets/metro/london/london.shp').to_crs(epsg=4326)
paris = geopandas.read_file('C:/Users/Zaca/Documents/Datasets/metro/paris/paris.shp').to_crs(epsg=4326)
beijing = geopandas.read_file('C:/Users/Zaca/Documents/Datasets/metro/beijing/Beijing.shp').to_crs(epsg=4326)
barcelona = geopandas.read_file('C:/Users/Zaca/Documents/Datasets/metro/barcelona/fuck/BCN_Fronterers_Trams_ETRS89_SHP.shp').to_crs(epsg=4326)
barcelona
# Out:
#                       NCarrer C_Carrer C_Parc C_Illa Solar  \
# 0              Moll d'Espanya   541576   None   None  None
# 1             Av. d'Esplugues   115400   None   None  None
# 2    Platja de la Nova Icària   700642   None   None  None
# 3         Camí de Can Balasch   058532   None   None  None
# 4               Pl. Catalunya   074404   None   None  None
# ..                        ...      ...    ...    ...   ...
# 318            Moll de Gregal   700697   None   None  None
# 319    Escullera del Poblenou   700820   None   None  None
# 320             Moll de Xaloc   700821   None   None  None
# 321            Moll de Gregal   700697   None   None  None
# 322           Moll de Mestral   700696   None   None  None
#
#                                       Frontera   Limita       Limit_A  \
# 0                           Districte 01 - Mar      Mar  Districte 01
# 1    Districte 04 - T.M.Esplugues de Llobregat    Vials  Districte 04
# 2                           Districte 10 - Mar      Mar  Districte 10
# 3       Districte 05 - T.M.St.Cugat del Vallès  Finques  Districte 05
# 4                  Districte 01 - Districte 02    Vials  Districte 01
# ..                                         ...      ...           ...
# 318                         Districte 10 - Mar      Mar  Districte 10
# 319                         Districte 10 - Mar      Mar  Districte 10
# 320                         Districte 10 - Mar      Mar  Districte 10
# 321                         Districte 10 - Mar      Mar  Districte 10
# 322                         Districte 10 - Mar      Mar  Districte 10
#
#                          Limit_B C_Tram1 C_Tram2     Longitud  \
# 0               Mar Mediterrània  D01-35    None   536.374910
# 1    T.M. Esplugues de Llobregat  D04-30    None   590.917020
# 2               Mar Mediterrània  D10-39    None   408.643763
# 3       T.M. St.Cugat del Vallès  D05-11    None  3400.233804
# 4                   Districte 02  D01-01  D02-16   203.460093
# ..                           ...     ...     ...          ...
# 318             Mar Mediterrània  D10-40    None   268.617876
# 319             Mar Mediterrània  D10-41    None  1081.266237
# 320             Mar Mediterrània  D10-42    None   527.569731
# 321             Mar Mediterrània  D10-43    None   182.126566
# 322             Mar Mediterrània  D10-44    None   243.484588
#
#                                               geometry
# 0    LINESTRING (2.18151 41.37509, 2.18142 41.37537...
# 1    LINESTRING (2.10009 41.38986, 2.10008 41.38990...
# 2    LINESTRING (2.20500 41.39090, 2.20211 41.39000...
# 3    LINESTRING (2.08015 41.42402, 2.08015 41.42403...
# 4    LINESTRING (2.17004 41.38547, 2.17138 41.38692...
# ..                                                 ...
# 318  LINESTRING (2.20141 41.38878, 2.20276 41.38777...
# 319  LINESTRING (2.20368 41.38742, 2.20336 41.38687...
# 320  LINESTRING (2.20240 41.38680, 2.20128 41.38597...
# 321  LINESTRING (2.20188 41.38719, 2.20046 41.38827...
# 322  LINESTRING (2.20034 41.38818, 2.20022 41.38827...
#
# [323 rows x 13 columns]

# %%
barcelona2 = pd.DataFrame(Polygon([[p.x, p.y] for p in barcelona['geometry']]))
barcelona2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-61930a3d05e1> in <module>
# ----> 1 barcelona2 = pd.DataFrame(Polygon([[p.x, p.y] for p in barcelona['geometry']]))
#       2 barcelona2
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     483                 )
#     484             else:
# --> 485                 raise ValueError("DataFrame constructor not properly called!")
#     486
#     487         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
metro_raw = pd.read_json('C:/Users/Zaca/Documents/Datasets/metro/paris/paris_subway.geojson')
metro = json_normalize(metro_raw['features'])

#metro['properties.relations'] = metro['properties.relations'].apply(lambda x: pd.Series())

paris_stations = metro.loc[metro['geometry.type'] == 'MultiPoint', 'geometry.coordinates']
paris_stations = [x[0] for x in paris_stations]
paris_stations = [Point(x, y) for x, y in paris_stations]
paris_stations = [point for point in paris_stations if point.within(paris.unary_union)]

# %%
ax = geoplot.polyplot(barcelona, figsize=(10, 10), lw= .25);
#for p in paris_stations:  
#    ax.scatter(p.x, p.y, facecolor='r', edgecolor='k', s=50);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\geoplot\geoplot.py in draw(self)
#     863                     try:  # Duck test for MultiPolygon.
# --> 864                         for subgeom in geom:
#     865                             feature = descartes.PolygonPatch(
#
# TypeError: 'LineString' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-de49367d0dbf> in <module>
# ----> 1 ax = geoplot.polyplot(barcelona, figsize=(10, 10), lw= .25);
#       2 #for p in paris_stations:
#       3 #    ax.scatter(p.x, p.y, facecolor='r', edgecolor='k', s=50);
#
# ~\Anaconda3\lib\site-packages\geoplot\geoplot.py in polyplot(df, projection, extent, figsize, ax, **kwargs)
#     878
#     879     plot = PolyPlot(df, figsize=figsize, ax=ax, extent=extent, projection=projection, **kwargs)
# --> 880     return plot.draw()
#     881
#     882
#
# ~\Anaconda3\lib\site-packages\geoplot\geoplot.py in draw(self)
#     871                         feature = descartes.PolygonPatch(
#     872                             geom, facecolor=facecolor, edgecolor=edgecolor, zorder=zorder,
# --> 873                             **kwargs
#     874                         )
#     875                         ax.add_patch(feature)
#
# ~\Anaconda3\lib\site-packages\descartes\patch.py in PolygonPatch(polygon, **kwargs)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# ~\Anaconda3\lib\site-packages\descartes\patch.py in PolygonPath(polygon)
#      47         else:
#      48             raise ValueError(
# ---> 49                 "A polygon or multi-polygon representation is required")
#      50
#      51     else:  # GeoJSON
#
# ValueError: A polygon or multi-polygon representation is required
